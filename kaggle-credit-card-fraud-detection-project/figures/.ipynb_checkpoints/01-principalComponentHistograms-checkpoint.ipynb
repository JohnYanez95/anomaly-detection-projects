# %%
# %run G:/Programs/Python/anomaly-detection-projects/kaggle-credit-card-fraud-detection-project/misc/01-plotPrincipalComponentColumns.ipynb

# %% [markdown]
# As a means to understand the underlying principal components I plotted the histograms to observe any out of unique behavior that could be emergent among the distributions.

# %%
import os
import pandas as pd
dataPath = '../data/creditcard.csv'
df_pd = pd.read_csv(dataPath)
plotPrincipalComponentColumns(df_pd = df_pd,
                              bins  = 30
                             )

# %% [markdown]
# The above demonstrates that some of the principal components have the emergent of approximately normal distributions, this includes:
# * V4, V9, V11, V12, V13, V15, V18, V19, V24, V25
#
# While the remaining appears to be left skewed or singleton binned in nature, with the exception of left skewness from:
# * V17, V20, V21, V23
#
# For now, there is no clear information that we can gather from the distributions
